# %%
import datetime
import pandas
import matplotlib.pyplot as plt
import seaborn
seaborn.set_style("whitegrid")
seaborn.despine()
# %matplotlib inline
# %config InlineBackend.figure_formats = {'svg',}

# %%
def create_timeline_entries(dates, values, colony, structure, parameter, unit, freq='B', interp_method='time'):
    """Create timeline entries to append"""
    # Create a date range
    date_range = pandas.date_range(start=dates[0], end=dates[-1], freq=freq)
    
    # Create a dataframe
    columns = ['datetime', 'event', 'colony', 'structure', 'parameter', 'value', 'unit']
    df = pandas.DataFrame(index=date_range, columns=columns)
    
    # Set values
    for date, value in zip(dates, values):
        df.loc[date, 'value'] = value
    
    # Interpolate
    df['value'] = pandas.to_numeric(df['value'])
    df['value'] = df['value'].interpolate(method=interp_method)
    
    # Set other columns
    df['datetime'] = date_range
    df['event'] = ['update' for i in range(0, len(date_range))]
    df['colony'] = [colony for i in range(0, len(date_range))]
    df['structure'] = [structure for i in range(0, len(date_range))]
    df['parameter'] = [parameter for i in range(0, len(date_range))]
    df['unit'] = [unit for i in range(0, len(date_range))]
    df['index'] = range(0, len(date_range))
    df.set_index('index', inplace=True)
    return df

# %%
# Create the init section
timeline = pandas.read_excel('init_timeline.xlsx')

# Create the update section
start = '2025-07-17 12:00:00'
end = '2030-07-30 12:00:00'
date_range = pandas.date_range(start=start, end=end, freq='M')
dates = [date_range[0], date_range[-1]]
values = [0.6, 6]
df = create_timeline_entries(
    dates, values, 'earth', 'booster_factory',
    'production', 'unit', freq='M', interp_method='time')
timeline = pandas.concat([timeline, df], axis=0)


dates = [date_range[0], date_range[-1]]
values = [0.5, 5]
df = create_timeline_entries(
    dates, values, 'earth', 'tank_factory',
    'production', 'unit', freq='M', interp_method='time')
timeline = pandas.concat([timeline, df], axis=0)


dates = [date_range[0], date_range[-1]]
values = [0.1, 1]
df = create_timeline_entries(
    dates, values, 'earth', 'heartofgold_factory',
    'production', 'unit', freq='M', interp_method='time')
timeline = pandas.concat([timeline, df], axis=0)

# %%
# Create launch window table
openning_dates = pandas.date_range(start=datetime.datetime(2018, 4, 1, 0, 0, 0), end=end, freq='780D').tolist()
launch_window = pandas.DataFrame(data={'datetime': openning_dates,
                                       'event': ['window_open'] * len(openning_dates),
                                       'colony': [None] * len(openning_dates),
                                       'colony': [None] * len(openning_dates),
                                       'structure': [None] * len(openning_dates),
                                       'parameter': [None] * len(openning_dates),
                                       'value': [None] * len(openning_dates),
                                       'unit': [None] * len(openning_dates)})
timeline = pandas.concat([timeline, launch_window], axis=0)

# %%
# Order by time the table
timeline = timeline.sort_values(by='datetime')
timeline.reset_index(inplace=True, drop=True)

# Save to excel
writer = pandas.ExcelWriter('timeline.xlsx')
timeline.to_excel(writer)
writer.save()

# %%
timeline
# Out:
#     colony            datetime        event   parameter             structure  \
# 0     None 2018-04-01 00:00:00  window_open        None                  None
# 1     None 2020-05-20 00:00:00  window_open        None                  None
# 2     None 2022-07-09 00:00:00  window_open        None                  None
# 3     None 2024-08-27 00:00:00  window_open        None                  None
# 4    earth 2025-06-17 12:00:00      initial  production       booster_factory
# 5    earth 2025-06-17 12:00:00      initial  production   heartofgold_factory
# 6    earth 2025-06-17 12:00:00      initial        rate          tank_factory
# 7    earth 2025-06-17 12:00:00      initial  production          tank_factory
# 8    earth 2025-06-17 12:00:00      initial       stock  propellant_container
# 9    earth 2025-06-17 12:00:00      initial       stock       booster_storage
# 10   earth 2025-06-17 12:00:00      initial       stock          tank_storage
# 11   earth 2025-06-17 12:00:00      initial        rate    propellant_factory
# 12   earth 2025-06-17 12:00:00      initial       stock   heartofgold_storage
# 13   earth 2025-06-17 12:00:00      initial        rate       booster_factory
# 14   earth 2025-06-17 12:00:00      initial  production    propellant_factory
# 15   earth 2025-06-17 12:00:00      initial        rate   heartofgold_factory
# 16   earth 2025-07-31 12:00:00       update  production       booster_factory
# 17   earth 2025-07-31 12:00:00       update  production   heartofgold_factory
# 18   earth 2025-07-31 12:00:00       update  production          tank_factory
# 19   earth 2025-08-31 12:00:00       update  production   heartofgold_factory
# 20   earth 2025-08-31 12:00:00       update  production          tank_factory
# 21   earth 2025-08-31 12:00:00       update  production       booster_factory
# 22   earth 2025-09-30 12:00:00       update  production          tank_factory
# 23   earth 2025-09-30 12:00:00       update  production       booster_factory
# 24   earth 2025-09-30 12:00:00       update  production   heartofgold_factory
# 25   earth 2025-10-31 12:00:00       update  production          tank_factory
# 26   earth 2025-10-31 12:00:00       update  production   heartofgold_factory
# 27   earth 2025-10-31 12:00:00       update  production       booster_factory
# 28   earth 2025-11-30 12:00:00       update  production       booster_factory
# 29   earth 2025-11-30 12:00:00       update  production          tank_factory
# ..     ...                 ...          ...         ...                   ...
# 168  earth 2029-09-30 12:00:00       update  production          tank_factory
# 169  earth 2029-09-30 12:00:00       update  production       booster_factory
# 170  earth 2029-09-30 12:00:00       update  production   heartofgold_factory
# 171  earth 2029-10-31 12:00:00       update  production       booster_factory
# 172  earth 2029-10-31 12:00:00       update  production          tank_factory
# 173  earth 2029-10-31 12:00:00       update  production   heartofgold_factory
# 174  earth 2029-11-30 12:00:00       update  production          tank_factory
# 175  earth 2029-11-30 12:00:00       update  production   heartofgold_factory
# 176  earth 2029-11-30 12:00:00       update  production       booster_factory
# 177  earth 2029-12-31 12:00:00       update  production          tank_factory
# 178  earth 2029-12-31 12:00:00       update  production       booster_factory
# 179  earth 2029-12-31 12:00:00       update  production   heartofgold_factory
# 180  earth 2030-01-31 12:00:00       update  production   heartofgold_factory
# 181  earth 2030-01-31 12:00:00       update  production       booster_factory
# 182  earth 2030-01-31 12:00:00       update  production          tank_factory
# 183  earth 2030-02-28 12:00:00       update  production   heartofgold_factory
# 184  earth 2030-02-28 12:00:00       update  production          tank_factory
# 185  earth 2030-02-28 12:00:00       update  production       booster_factory
# 186  earth 2030-03-31 12:00:00       update  production   heartofgold_factory
# 187  earth 2030-03-31 12:00:00       update  production       booster_factory
# 188  earth 2030-03-31 12:00:00       update  production          tank_factory
# 189  earth 2030-04-30 12:00:00       update  production          tank_factory
# 190  earth 2030-04-30 12:00:00       update  production       booster_factory
# 191  earth 2030-04-30 12:00:00       update  production   heartofgold_factory
# 192  earth 2030-05-31 12:00:00       update  production       booster_factory
# 193  earth 2030-05-31 12:00:00       update  production   heartofgold_factory
# 194  earth 2030-05-31 12:00:00       update  production          tank_factory
# 195  earth 2030-06-30 12:00:00       update  production       booster_factory
# 196  earth 2030-06-30 12:00:00       update  production          tank_factory
# 197  earth 2030-06-30 12:00:00       update  production   heartofgold_factory
#
#         unit      value
# 0       None       None
# 1       None       None
# 2       None       None
# 3       None       None
# 4       unit        0.6
# 5       unit        0.1
# 6    seconds  2.592e+06
# 7       unit        0.5
# 8       unit         10
# 9       unit          6
# 10      unit          5
# 11   seconds  2.592e+06
# 12      unit          1
# 13   seconds  2.592e+06
# 14      unit          1
# 15   seconds  2.592e+06
# 16      unit        0.6
# 17      unit        0.1
# 18      unit        0.5
# 19      unit   0.115543
# 20      unit   0.577716
# 21      unit   0.693259
# 22      unit   0.652925
# 23      unit    0.78351
# 24      unit   0.130585
# 25      unit   0.730641
# 26      unit   0.146128
# 27      unit   0.876769
# 28      unit   0.967019
# 29      unit    0.80585
# ..       ...        ...
# 168     unit     4.3156
# 169     unit    5.17872
# 170     unit    0.86312
# 171     unit    5.27198
# 172     unit    4.39331
# 173     unit   0.878663
# 174     unit    4.46852
# 175     unit   0.893705
# 176     unit    5.36223
# 177     unit    4.54624
# 178     unit    5.45549
# 179     unit   0.909248
# 180     unit   0.924791
# 181     unit    5.54875
# 182     unit    4.62396
# 183     unit    0.93883
# 184     unit    4.69415
# 185     unit    5.63298
# 186     unit   0.954373
# 187     unit    5.72624
# 188     unit    4.77187
# 189     unit    4.84708
# 190     unit    5.81649
# 191     unit   0.969415
# 192     unit    5.90975
# 193     unit   0.984958
# 194     unit    4.92479
# 195     unit          6
# 196     unit          5
# 197     unit          1
#
# [198 rows x 7 columns]
