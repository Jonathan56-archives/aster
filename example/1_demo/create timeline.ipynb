# %%
import pandas
import matplotlib.pyplot as plt
import seaborn
seaborn.set_style("whitegrid")
seaborn.despine()
# %matplotlib inline
# %config InlineBackend.figure_formats = {'svg',}

# %%
timeline = pandas.read_excel('timeline.xlsx')

# %%
def create_timeline_entries(dates, values, colony, structure, parameter, unit, freq='B', interp_method='time'):
    """Create timeline entries to append"""
    # Create a date range
    date_range = pandas.date_range(start=dates[0], end=dates[-1], freq=freq)
    
    # Create a dataframe
    columns = ['datetime', 'event', 'colony', 'structure', 'parameter', 'value', 'unit']
    df = pandas.DataFrame(index=date_range, columns=columns)
    
    # Set values
    for date, value in zip(dates, values):
        df.loc[date, 'value'] = value
    
    # Interpolate
    df['value'] = pandas.to_numeric(df['value'])
    df['value'] = df['value'].interpolate(method=interp_method)
    
    # Set other columns
    df['datetime'] = date_range
    df['event'] = ['update' for i in range(0, len(date_range))]
    df['colony'] = [template['colony'] for i in range(0, len(date_range))]
    df['structure'] = [template['structure'] for i in range(0, len(date_range))]
    df['parameter'] = [template['parameter'] for i in range(0, len(date_range))]
    df['unit'] = [template['unit'] for i in range(0, len(date_range))]
    df['index'] = range(0, len(date_range))
    df.set_index('index', inplace=True)
    return df

# %%
# Create the init section
timeline = pandas.read_excel('timeline.xlsx')


# Create the update section
start = '2025-07-17 12:00:00'
end = '2030-07-30 12:00:00'
date_range = pandas.date_range(start=start, end=end, freq='M')
dates = [date_range[0], date_range[-1]]
values = [0.6, 6]
df = create_timeline_entries(
    dates, values, 'earth', 'booster_factory',
    'production', 'unit', freq='M', interp_method='time')
timeline = pandas.concat([timeline, df], axis=0)


dates = [date_range[0], date_range[-1]]
values = [0.5, 5]
df = create_timeline_entries(
    dates, values, 'earth', 'tank_factory',
    'production', 'unit', freq='M', interp_method='time')
timeline = pandas.concat([timeline, df], axis=0)


dates = [date_range[0], date_range[-1]]
values = [0.1, 1]
df = create_timeline_entries(
    dates, values, 'earth', 'heartofgold_factory',
    'production', 'unit', freq='M', interp_method='time')
timeline = pandas.concat([timeline, df], axis=0)

# %%
timeline
# Out:
#               datetime    event colony             structure   parameter  \
# 0  2025-06-17 12:00:00  initial  earth  propellant_container       stock
# 1  2025-06-17 12:00:00  initial  earth       booster_storage       stock
# 2  2025-06-17 12:00:00  initial  earth          tank_storage       stock
# 3  2025-06-17 12:00:00  initial  earth   heartofgold_storage       stock
# 4  2025-06-17 12:00:00  initial  earth    propellant_factory  production
# 5  2025-06-17 12:00:00  initial  earth    propellant_factory        rate
# 6  2025-06-17 12:00:00  initial  earth       booster_factory  production
# 7  2025-06-17 12:00:00  initial  earth       booster_factory        rate
# 8  2025-06-17 12:00:00  initial  earth          tank_factory  production
# 9  2025-06-17 12:00:00  initial  earth          tank_factory        rate
# 10 2025-06-17 12:00:00  initial  earth   heartofgold_factory  production
# 11 2025-06-17 12:00:00  initial  earth   heartofgold_factory        rate
# 0  2025-07-31 12:00:00   update  earth       booster_factory  production
# 1  2025-08-31 12:00:00   update  earth       booster_factory  production
# 2  2025-09-30 12:00:00   update  earth       booster_factory  production
# 3  2025-10-31 12:00:00   update  earth       booster_factory  production
# 4  2025-11-30 12:00:00   update  earth       booster_factory  production
# 5  2025-12-31 12:00:00   update  earth       booster_factory  production
# 6  2026-01-31 12:00:00   update  earth       booster_factory  production
# 7  2026-02-28 12:00:00   update  earth       booster_factory  production
# 8  2026-03-31 12:00:00   update  earth       booster_factory  production
# 9  2026-04-30 12:00:00   update  earth       booster_factory  production
# 10 2026-05-31 12:00:00   update  earth       booster_factory  production
# 11 2026-06-30 12:00:00   update  earth       booster_factory  production
# 12 2026-07-31 12:00:00   update  earth       booster_factory  production
# 13 2026-08-31 12:00:00   update  earth       booster_factory  production
# 14 2026-09-30 12:00:00   update  earth       booster_factory  production
# 15 2026-10-31 12:00:00   update  earth       booster_factory  production
# 16 2026-11-30 12:00:00   update  earth       booster_factory  production
# 17 2026-12-31 12:00:00   update  earth       booster_factory  production
# ..                 ...      ...    ...                   ...         ...
# 30 2028-01-31 12:00:00   update  earth       booster_factory  production
# 31 2028-02-29 12:00:00   update  earth       booster_factory  production
# 32 2028-03-31 12:00:00   update  earth       booster_factory  production
# 33 2028-04-30 12:00:00   update  earth       booster_factory  production
# 34 2028-05-31 12:00:00   update  earth       booster_factory  production
# 35 2028-06-30 12:00:00   update  earth       booster_factory  production
# 36 2028-07-31 12:00:00   update  earth       booster_factory  production
# 37 2028-08-31 12:00:00   update  earth       booster_factory  production
# 38 2028-09-30 12:00:00   update  earth       booster_factory  production
# 39 2028-10-31 12:00:00   update  earth       booster_factory  production
# 40 2028-11-30 12:00:00   update  earth       booster_factory  production
# 41 2028-12-31 12:00:00   update  earth       booster_factory  production
# 42 2029-01-31 12:00:00   update  earth       booster_factory  production
# 43 2029-02-28 12:00:00   update  earth       booster_factory  production
# 44 2029-03-31 12:00:00   update  earth       booster_factory  production
# 45 2029-04-30 12:00:00   update  earth       booster_factory  production
# 46 2029-05-31 12:00:00   update  earth       booster_factory  production
# 47 2029-06-30 12:00:00   update  earth       booster_factory  production
# 48 2029-07-31 12:00:00   update  earth       booster_factory  production
# 49 2029-08-31 12:00:00   update  earth       booster_factory  production
# 50 2029-09-30 12:00:00   update  earth       booster_factory  production
# 51 2029-10-31 12:00:00   update  earth       booster_factory  production
# 52 2029-11-30 12:00:00   update  earth       booster_factory  production
# 53 2029-12-31 12:00:00   update  earth       booster_factory  production
# 54 2030-01-31 12:00:00   update  earth       booster_factory  production
# 55 2030-02-28 12:00:00   update  earth       booster_factory  production
# 56 2030-03-31 12:00:00   update  earth       booster_factory  production
# 57 2030-04-30 12:00:00   update  earth       booster_factory  production
# 58 2030-05-31 12:00:00   update  earth       booster_factory  production
# 59 2030-06-30 12:00:00   update  earth       booster_factory  production
#
#            value     unit
# 0   1.000000e+01     unit
# 1   6.000000e+00     unit
# 2   5.000000e+00     unit
# 3   1.000000e+00     unit
# 4   1.000000e+00     unit
# 5   2.592000e+06  seconds
# 6   6.000000e-01     unit
# 7   2.592000e+06  seconds
# 8   5.000000e-01     unit
# 9   2.592000e+06  seconds
# 10  1.000000e-01     unit
# 11  2.592000e+06  seconds
# 0   6.000000e-01     unit
# 1   6.932591e-01     unit
# 2   7.835097e-01     unit
# 3   8.767688e-01     unit
# 4   9.670195e-01     unit
# 5   1.060279e+00     unit
# 6   1.153538e+00     unit
# 7   1.237772e+00     unit
# 8   1.331031e+00     unit
# 9   1.421281e+00     unit
# 10  1.514540e+00     unit
# 11  1.604791e+00     unit
# 12  1.698050e+00     unit
# 13  1.791309e+00     unit
# 14  1.881560e+00     unit
# 15  1.974819e+00     unit
# 16  2.065070e+00     unit
# 17  2.158329e+00     unit
# ..           ...      ...
# 30  5.582730e-01     unit
# 31  5.728134e-01     unit
# 32  5.883565e-01     unit
# 33  6.033983e-01     unit
# 34  6.189415e-01     unit
# 35  6.339833e-01     unit
# 36  6.495265e-01     unit
# 37  6.650696e-01     unit
# 38  6.801114e-01     unit
# 39  6.956546e-01     unit
# 40  7.106964e-01     unit
# 41  7.262396e-01     unit
# 42  7.417827e-01     unit
# 43  7.558217e-01     unit
# 44  7.713649e-01     unit
# 45  7.864067e-01     unit
# 46  8.019499e-01     unit
# 47  8.169916e-01     unit
# 48  8.325348e-01     unit
# 49  8.480780e-01     unit
# 50  8.631198e-01     unit
# 51  8.786630e-01     unit
# 52  8.937047e-01     unit
# 53  9.092479e-01     unit
# 54  9.247911e-01     unit
# 55  9.388301e-01     unit
# 56  9.543733e-01     unit
# 57  9.694150e-01     unit
# 58  9.849582e-01     unit
# 59  1.000000e+00     unit
#
# [192 rows x 7 columns]
